# %%
import requests
import yaml

# Load config
with open('../config.yaml', 'r') as file:
    config = yaml.safe_load(file)

# Get API URL from config
API_URL = config['custom_llm']['url']
MODEL = config['custom_llm']['model']

print(f"API URL: {API_URL}")
print(f"Model: {MODEL}")

request_data = {
    "model": MODEL,
    "messages": [
        {"role": "system", "content": "You are a helpful asssistant"},
        {"role": "user", "content": "Mày là ai?"}
    ]
}

headers = {"Content-Type": "application/json"}
response = requests.post(API_URL, headers=headers, json=request_data)
response.raise_for_status()

from pprint import pprint
pprint(response.json())
# Out:
# API URL: https://a407a78630b9.ngrok-free.app/v1/chat/completions
# Model: meta-llama/Llama-3.1-8B-Instruct
# {'choices': [{'finish_reason': 'stop',
#               'index': 0,
#               'logprobs': None,
#               'message': {'annotations': None,
#                           'audio': None,
#                           'content': 'Tôi là một trợ lý ảo, một chương trình '
#                                      'máy tính được thiết kế để hỗ trợ và cung '
#                                      'cấp thông tin cho người dùng. Tôi có thể '
#                                      'trả lời các câu hỏi, cung cấp thông tin '
#                                      'về các chủ đề khác nhau, giúp viết văn '
#                                      'bản và thậm chí còn có thể trò chuyện '
#                                      'với người dùng như một cuộc trò chuyện '
#                                      'thông thường.\n'
#                                      '\n'
#                                      'Tôi không phải là một con người, nhưng '
#                                      'tôi đã được đào tạo trên một lượng lớn '
#                                      'dữ liệu để có thể hiểu và phản ứng với '
#                                      'các câu hỏi và yêu cầu của người dùng. '
#                                      'Tôi sẵn sàng giúp đỡ bạn với bất kỳ điều '
#                                      'gì bạn cần!',
#                           'function_call': None,
#                           'reasoning_content': None,
#                           'refusal': None,
#                           'role': 'assistant',
#                           'tool_calls': []},
#               'stop_reason': None,
#               'token_ids': None}],
#  'created': 1765635244,
#  'id': 'chatcmpl-f2a0551333a54c829f95f01199d71c31',
#  'kv_transfer_params': None,
#  'model': 'meta-llama/Llama-3.1-8B-Instruct',
#  'object': 'chat.completion',
#  'prompt_logprobs': None,
#  'prompt_token_ids': None,
#  'service_tier': None,
#  'system_fingerprint': None,
#  'usage': {'completion_tokens': 124,
#            'prompt_tokens': 47,
#            'prompt_tokens_details': None,
#            'total_tokens': 171}}
